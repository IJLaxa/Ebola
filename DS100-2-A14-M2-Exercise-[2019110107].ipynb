# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows',None)
data = pd.read_csv('https://raw.githubusercontent.com/IJLaxa/Ebola/main/ebola_2014_2016_clean.csv')
Country_data = data.loc[data['Country'].str.contains('Nigeria|Liberia',regex=True)]
Country_data
# Out:
#       Country        Date  \
# 1     Nigeria  2014-08-29
# 3     Liberia  2014-08-29
# 5     Nigeria  2014-09-05
# 6     Liberia  2014-09-05
# 12    Liberia  2014-09-08
# 13    Nigeria  2014-09-08
# 16    Nigeria  2014-09-12
# 17    Liberia  2014-09-12
# 22    Nigeria  2014-09-16
# 23    Liberia  2014-09-16
# 24    Nigeria  2014-09-18
# 27    Liberia  2014-09-18
# 29    Nigeria  2014-09-22
# 31    Liberia  2014-09-22
# 34    Liberia  2014-09-24
# 36    Nigeria  2014-09-24
# 40    Liberia  2014-09-26
# 43    Nigeria  2014-09-26
# 46    Nigeria  2014-10-01
# 48    Liberia  2014-10-01
# 50    Nigeria  2014-10-03
# 52    Liberia  2014-10-03
# 55    Nigeria  2014-10-08
# 60    Liberia  2014-10-08
# 63    Liberia  2014-10-10
# 64    Nigeria  2014-10-10
# 70    Nigeria  2014-10-15
# 71    Liberia  2014-10-15
# 76    Nigeria  2014-10-17
# 80    Liberia  2014-10-17
# 82    Nigeria  2014-10-22
# 87    Liberia  2014-10-22
# 94    Nigeria  2014-10-25
# 96    Liberia  2014-10-25
# ...

# %%
Country_data = Country_data.loc[Country_data['Date'].str.contains('2014-08|2014-12')]
Country_data
# Out:
#      Country        Date  \
# 1    Nigeria  2014-08-29
# 3    Liberia  2014-08-29
# 173  Liberia  2014-12-01
# 174  Nigeria  2014-12-01
# 182  Liberia  2014-12-03
# 184  Nigeria  2014-12-03
# 189  Liberia  2014-12-10
# 191  Nigeria  2014-12-10
# 194  Nigeria  2014-12-15
# 198  Liberia  2014-12-15
# 201  Nigeria  2014-12-17
# 204  Liberia  2014-12-17
# 211  Nigeria  2014-12-22
# 214  Liberia  2014-12-22
# 220  Liberia  2014-12-23
# 223  Nigeria  2014-12-23
# 225  Nigeria  2014-12-24
# 231  Liberia  2014-12-24
# 237  Nigeria  2014-12-26
# 239  Liberia  2014-12-26
# 243  Nigeria  2014-12-29
# 245  Liberia  2014-12-29
# 252  Liberia  2014-12-30
# 256  Nigeria  2014-12-30
# 259  Liberia  2014-12-31
# 262  Nigeria  2014-12-31
#
#      Cumulative no. of confirmed, probable and suspected cases  \
# 1                                                 19.0
# 3                                               1378.0
# 173                                             7635.0
# ...

# %%
Country_data['Date'] = pd.to_datetime(Country_data['Date'])
desired_months = ['August', 'September', 'October', 'November', 'December']
Country_data = Country_data.loc[(Country_data['Date'].dt.strftime('%B').isin(desired_months)) & (Country_data['Date'].dt.year == 2014)]
Country_data['Date'] = Country_data['Date'].dt.strftime('%Y-%m-%d')
Country_data
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4900\4049725332.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Country_data['Date'] = pd.to_datetime(Country_data['Date'])
#      Country        Date  \
# 1    Nigeria  2014-08-29
# 3    Liberia  2014-08-29
# 173  Liberia  2014-12-01
# 174  Nigeria  2014-12-01
# 182  Liberia  2014-12-03
# 184  Nigeria  2014-12-03
# 189  Liberia  2014-12-10
# 191  Nigeria  2014-12-10
# 194  Nigeria  2014-12-15
# 198  Liberia  2014-12-15
# 201  Nigeria  2014-12-17
# 204  Liberia  2014-12-17
# 211  Nigeria  2014-12-22
# 214  Liberia  2014-12-22
# 220  Liberia  2014-12-23
# 223  Nigeria  2014-12-23
# 225  Nigeria  2014-12-24
# 231  Liberia  2014-12-24
# 237  Nigeria  2014-12-26
# 239  Liberia  2014-12-26
# ...

# %%
Country_data['CFR'] = np.round(data['Cumulative no. of confirmed, probable and suspected deaths']/data['Cumulative no. of confirmed, probable and suspected cases']*100,3)
Country_data
# Out:
#      Country        Date  \
# 1    Nigeria  2014-08-29
# 3    Liberia  2014-08-29
# 173  Liberia  2014-12-01
# 174  Nigeria  2014-12-01
# 182  Liberia  2014-12-03
# 184  Nigeria  2014-12-03
# 189  Liberia  2014-12-10
# 191  Nigeria  2014-12-10
# 194  Nigeria  2014-12-15
# 198  Liberia  2014-12-15
# 201  Nigeria  2014-12-17
# 204  Liberia  2014-12-17
# 211  Nigeria  2014-12-22
# 214  Liberia  2014-12-22
# 220  Liberia  2014-12-23
# 223  Nigeria  2014-12-23
# 225  Nigeria  2014-12-24
# 231  Liberia  2014-12-24
# 237  Nigeria  2014-12-26
# 239  Liberia  2014-12-26
# 243  Nigeria  2014-12-29
# 245  Liberia  2014-12-29
# 252  Liberia  2014-12-30
# 256  Nigeria  2014-12-30
# 259  Liberia  2014-12-31
# 262  Nigeria  2014-12-31
#
#      Cumulative no. of confirmed, probable and suspected cases  \
# 1                                                 19.0
# 3                                               1378.0
# 173                                             7635.0
# ...

# %%
df1 = Country_data.loc[Country_data['Country'].str.contains('Nigeria')]
df2 = Country_data.loc[Country_data['Country'].str.contains('Liberia')]
df1 = (df1.rename(columns={'Country': 'Country1','CFR':'CFR1'}))
df2 = (df2.rename(columns={'Country': 'Country2','CFR':'CFR2'}))
df1 = df1.drop(columns=['Cumulative no. of confirmed, probable and suspected cases','Cumulative no. of confirmed, probable and suspected cases'])
df2 = df2.drop(columns=['Cumulative no. of confirmed, probable and suspected cases','Cumulative no. of confirmed, probable and suspected deaths'])
abs_data = pd.merge(df1,df2)
abs_data[['Date','Country1','CFR1','Country2','CFR2']]
# Out:
#           Date Country1    CFR1 Country2    CFR2
# 0   2014-08-29  Nigeria  36.842  Liberia  50.363
# 1   2014-12-01  Nigeria  40.000  Liberia  41.192
# 2   2014-12-03  Nigeria  40.000  Liberia  41.192
# 3   2014-12-10  Nigeria  40.000  Liberia  41.158
# 4   2014-12-15  Nigeria  40.000  Liberia  42.196
# 5   2014-12-17  Nigeria  40.000  Liberia  42.196
# 6   2014-12-22  Nigeria  40.000  Liberia  43.116
# 7   2014-12-23  Nigeria  40.000  Liberia  43.116
# 8   2014-12-24  Nigeria  40.000  Liberia  43.042
# 9   2014-12-26  Nigeria  40.000  Liberia  43.042
# 10  2014-12-29  Nigeria  40.000  Liberia  42.786
# 11  2014-12-30  Nigeria  40.000  Liberia  42.786
# 12  2014-12-31  Nigeria  40.000  Liberia  42.691

# %%
abs_data['Absolute Difference'] = np.round(abs(abs_data['CFR1']-abs_data['CFR2']),3)
abs_data[['Date','Country1','CFR1','Country2','CFR2','Absolute Difference']]
# Out:
#           Date Country1    CFR1 Country2    CFR2  Absolute Difference
# 0   2014-08-29  Nigeria  36.842  Liberia  50.363               13.521
# 1   2014-12-01  Nigeria  40.000  Liberia  41.192                1.192
# 2   2014-12-03  Nigeria  40.000  Liberia  41.192                1.192
# 3   2014-12-10  Nigeria  40.000  Liberia  41.158                1.158
# 4   2014-12-15  Nigeria  40.000  Liberia  42.196                2.196
# 5   2014-12-17  Nigeria  40.000  Liberia  42.196                2.196
# 6   2014-12-22  Nigeria  40.000  Liberia  43.116                3.116
# 7   2014-12-23  Nigeria  40.000  Liberia  43.116                3.116
# 8   2014-12-24  Nigeria  40.000  Liberia  43.042                3.042
# 9   2014-12-26  Nigeria  40.000  Liberia  43.042                3.042
# 10  2014-12-29  Nigeria  40.000  Liberia  42.786                2.786
# 11  2014-12-30  Nigeria  40.000  Liberia  42.786                2.786
# ...

# %% [markdown]
# Daily New Cases

# %%
# %matplotlib notebook
data=pd.read_csv('ebola_2014_2016_clean.csv')
df_NIR=data.loc[data['Country'].str.contains('Nigeria',regex=True)]
df_LIBR=data.loc[data['Country'].str.contains('Liberia',regex=True)]
df=pd.concat([df_NIR,df_LIBR])

dailynewcases=df_NIR[['Date','Cumulative no. of confirmed, probable and suspected cases']]
graph=dailynewcases.plot.bar('Date','Cumulative no. of confirmed, probable and suspected cases',rot=30,color='blue',width=1)
plt.title('Daily New Cases in the Nigeria')
plt.xlabel('Dates')
plt.ylabel('Number of Cases')
plt.tight_layout()
ax = plt.gca()
ax.locator_params(nbins=12, axis='x')

dailynewcases=df_LIBR[['Date','Cumulative no. of confirmed, probable and suspected cases']]
graph=dailynewcases.plot.bar('Date','Cumulative no. of confirmed, probable and suspected cases',rot=30,color='green',width=1)
plt.title('Daily New Cases in the Liberia')
plt.xlabel('Dates')
plt.ylabel('Number of Cases')
plt.tight_layout()
ax = plt.gca()
ax.locator_params(nbins=12, axis='x')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Daily New Deaths

# %%
dailynewdeaths=df_NIR[['Date','Cumulative no. of confirmed, probable and suspected deaths']]
graph=dailynewdeaths.plot.bar('Date','Cumulative no. of confirmed, probable and suspected deaths',rot=30,color='blue',width=1)
plt.title('Daily New Deaths in the Nigeria')
plt.xlabel('Dates')
plt.ylabel('Number of Deaths')
plt.tight_layout()
ax = plt.gca()
ax.locator_params(nbins=12, axis='x')

dailynewdeaths=df_LIBR[['Date','Cumulative no. of confirmed, probable and suspected deaths']]
graph=dailynewdeaths.plot.bar('Date','Cumulative no. of confirmed, probable and suspected deaths',rot=30,color='green',width=1)
plt.title('Daily New Deaths in the Liberia')
plt.xlabel('Dates')
plt.ylabel('Number of Deaths')
plt.tight_layout()
ax = plt.gca()
ax.locator_params(nbins=12, axis='x')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pytz
ebola_df = pd.read_csv('ebola_2014_2016_clean.csv', parse_dates=['Date'])
nigeria_df = ebola_df[ebola_df['Country'] == 'Nigeria']
lagos_tz = pytz.timezone('Africa/Lagos')
nigeria_df['Date'] = pd.to_datetime(nigeria_df['Date']).dt.tz_localize(pytz.utc).dt.tz_convert(lagos_tz)
nigeria_df['CFR'] = nigeria_df['Cumulative no. of confirmed, probable and suspected deaths'] / nigeria_df['Cumulative no. of confirmed, probable and suspected cases']
fig, ax = plt.subplots()
ax.plot(nigeria_df['Date'], nigeria_df['CFR'])
ax.set_title('Ebola Outbreak in Nigeria (2014-2016)')
ax.set_xlabel('Date')
ax.set_ylabel('Case Fatality Ratio')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4900\2572098942.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nigeria_df['Date'] = pd.to_datetime(nigeria_df['Date']).dt.tz_localize(pytz.utc).dt.tz_convert(lagos_tz)
# C:\Users\user\AppData\Local\Temp\ipykernel_4900\2572098942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pytz

ebola_df = pd.read_csv('ebola_2014_2016_clean.csv', parse_dates=['Date'])
liberia_df = ebola_df[ebola_df['Country'] == 'Liberia']
lagos_tz = pytz.timezone('Africa/Lagos')
liberia_df['Date'] = pd.to_datetime(liberia_df['Date']).dt.tz_localize(pytz.utc).dt.tz_convert(lagos_tz)
liberia_df['CFR'] = liberia_df['Cumulative no. of confirmed, probable and suspected deaths'] / liberia_df['Cumulative no. of confirmed, probable and suspected cases']
fig, ax = plt.subplots()
ax.plot(liberia_df['Date'], liberia_df['CFR'])
ax.set_title('Ebola Outbreak in Liberia (2014-2016)')
ax.set_xlabel('Date')
ax.set_ylabel('Case Fatality Ratio')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4900\2895645883.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   liberia_df['Date'] = pd.to_datetime(liberia_df['Date']).dt.tz_localize(pytz.utc).dt.tz_convert(lagos_tz)
# C:\Users\user\AppData\Local\Temp\ipykernel_4900\2895645883.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# Load the cleaned Ebola dataset for Nigeria
ebola_df = pd.read_csv('ebola_2014_2016_clean.csv')
nigeria_df = ebola_df[ebola_df['Country'] == 'Nigeria']

# Compute the case fatality rate (CFR)
nigeria_df['CFR'] = nigeria_df['Cumulative no. of confirmed, probable and suspected deaths'] / nigeria_df['Cumulative no. of confirmed, probable and suspected cases']

# Convert the Date column to days since the first date
first_date = pd.to_datetime(nigeria_df['Date'].min())
nigeria_df['Days'] = (pd.to_datetime(nigeria_df['Date']) - first_date).dt.days

# Create a 3D figure
fig = plt.figure()
ax = plt.axes(projection='3d')

# Define the x, y, and z values
x = nigeria_df['Days']
y = nigeria_df['Cumulative no. of confirmed, probable and suspected cases']
z = nigeria_df['CFR']

# Plot the 3D surface
ax.plot_trisurf(x, y, z, cmap='viridis', edgecolor='none')

# Set the plot title and axis labels
ax.set_title('Case Fatality Rate (CFR) of Ebola in Nigeria')
ax.set_xlabel('Days since First Date')
ax.set_ylabel('Cumulative Number of Cases')
ax.set_zlabel('CFR')

# Show the plot
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4900\1368724745.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nigeria_df['CFR'] = nigeria_df['Cumulative no. of confirmed, probable and suspected deaths'] / nigeria_df['Cumulative no. of confirmed, probable and suspected cases']
# C:\Users\user\AppData\Local\Temp\ipykernel_4900\1368724745.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nigeria_df['Days'] = (pd.to_datetime(nigeria_df['Date']) - first_date).dt.days
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# Load the cleaned Ebola dataset for Liber
ebola_df = pd.read_csv('ebola_2014_2016_clean.csv')
Liberia_df = ebola_df[ebola_df['Country'] == 'Liberia']

# Compute the case fatality rate (CFR)
Liberia_df['CFR'] = Liberia_df['Cumulative no. of confirmed, probable and suspected deaths'] / Liberia_df['Cumulative no. of confirmed, probable and suspected cases']

# Convert the Date column to days since the first date
first_date = pd.to_datetime(Liberia_df['Date'].min())
Liberia_df['Days'] = (pd.to_datetime(Liberia_df['Date']) - first_date).dt.days

# Create a 3D figure
fig = plt.figure()
ax = plt.axes(projection='3d')

# Define the x, y, and z values
x = Liberia_df['Days']
y = Liberia_df['Cumulative no. of confirmed, probable and suspected cases']
z = Liberia_df['CFR']

# Plot the 3D surface
ax.plot_trisurf(x, y, z, cmap='viridis', edgecolor='none')

# Set the plot title and axis labels
ax.set_title('Case Fatality Rate (CFR) of Ebola in Liberia')
ax.set_xlabel('Days since First Date')
ax.set_ylabel('Cumulative Number of Cases')
ax.set_zlabel('CFR')

# Show the plot
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4900\1434020699.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Liberia_df['CFR'] = Liberia_df['Cumulative no. of confirmed, probable and suspected deaths'] / Liberia_df['Cumulative no. of confirmed, probable and suspected cases']
# C:\Users\user\AppData\Local\Temp\ipykernel_4900\1434020699.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Liberia_df['Days'] = (pd.to_datetime(Liberia_df['Date']) - first_date).dt.days
# ...

# %% [markdown]
# Animation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Load the data
ebola_df = pd.read_csv('ebola_2014_2016_clean.csv', parse_dates=['Date'])

# Filter for data from Nigeria only
Nigeria_df = ebola_df[ebola_df['Country'] == 'Nigeria']

# Calculate the CFR (Case Fatality Ratio)
nigeria_df['CFR'] = Nigeria_df['Cumulative no. of confirmed, probable and suspected deaths'] /Nigeria_df['Cumulative no. of confirmed, probable and suspected cases']

# Create a figure and axis object
fig, ax = plt.subplots()

# Define the update function for the animation
def update(num):
    # Clear the axis
    ax.clear()

    # Plot the CFR over time
    ax.plot(nigeria_df['Date'].iloc[:num], nigeria_df['CFR'].iloc[:num], color='blue')

    # Set the axis labels and title
    ax.set_xlabel('Date')
    ax.set_ylabel('Case Fatality Ratio')
    ax.set_title('Ebola Outbreak in Nigeria (2014-2016)')

# Create the animation
ani = animation.FuncAnimation(fig, update, frames=nigeria_df.shape[0], interval=100)

# Display the animation
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Load the data
ebola_df = pd.read_csv('ebola_2014_2016_clean.csv', parse_dates=['Date'])

# Filter for data from Nigeria only
Liberia_df = ebola_df[ebola_df['Country'] == 'Liberia']

# Calculate the CFR (Case Fatality Ratio)
Liberia_df['CFR'] =Liberia_df['Cumulative no. of confirmed, probable and suspected deaths'] /Liberia_df['Cumulative no. of confirmed, probable and suspected cases']

# Create a figure and axis object
fig, ax = plt.subplots()

# Define the update function for the animation
def update(num):
    # Clear the axis
    ax.clear()

    # Plot the CFR over time
    ax.plot(Liberia_df['Date'].iloc[:num],Liberia_df['CFR'].iloc[:num], color='red')

    # Set the axis labels and title
    ax.set_xlabel('Date')
    ax.set_ylabel('Case Fatality Ratio')
    ax.set_title('Ebola Outbreak in Liberia (2014-2016)')

# Create the animation
ani = animation.FuncAnimation(fig, update, frames=nigeria_df.shape[0], interval=100)

# Display the animation
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4900\1414115399.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Liberia_df['CFR'] =Liberia_df['Cumulative no. of confirmed, probable and suspected deaths'] /Liberia_df['Cumulative no. of confirmed, probable and suspected cases']
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Discussion: The data used in this Matplotlib shows the case fatality rate (CFR) of Ebola in Liberia over time, based on the cleaned Ebola dataset for 2014-2016. The CFR is computed as the ratio of the cumulative number of deaths to the cumulative number of confirmed, probable, and suspected cases.The plot shows the relationship between the number of days since the first date of the Ebola outbreak in Liberia, the cumulative number of cases, and the CFR. The x-axis shows the number of days since the first date of the Ebola outbreak, the y-axis shows the cumulative number of cases, and the z-axis shows the CFR. For example the 3D surface plot is colored using the "viridis" colormap, which maps low values to blue and high values to yellow.
#
# The plot reveals some interesting insights. For example, we can see that the CFR was initially high when the outbreak started, but it decreased over time as more cases were reported and better treatment methods were developed. We can also see that there were periods of time when the CFR increased temporarily, which may have been due to factors such as changes in the virus or delays in treatment.Overall, this Matplotlib 3D plot is a useful tool for visualizing the relationship between multiple variables in the Ebola dataset for Liberia. It allows us to see trends and patterns that may not be apparent from a 2D plot, and it provides insights into the dynamics of the Ebola outbreak in Liberia over time.
#
# Inno Jose D. Laxa
# 2019110107
